# %%
import matplotlib.pyplot as plt
import numpy as np
x=[1,2,3,4,5,6]
y=[7,8,9,2,6,5]
plt.subplot(2,2,1)
plt.plot(x,y,marker='X')


x=[1,2,3,4,5,6]
y=['kasdk','lla','jmnsa','ksnfa','jsl','nsahk']
my_explode=[0,0.8,0,0.2,0.4,0]
plt.subplot(2,2,2)
plt.pie(x,labels=y,explode=my_explode)
plt.legend(loc=)


x=[1,2,3,4,5,6]
y=[7,8,9,2,6,5]
plt.subplot(2,2,3)

plt.bar(x,y,width=0.2)


plt.subplot(2,2,4)
plt.scatter(x,y)
plt.show()

# %%
w = 5
h = 8
d = 45
plt.figure(figsize=(w,h),dpi = d)
plt.axis([0,5,8,9])
x = [2,5,8]
y = [1,5,0.9]
label_x = 5
label_y = 4
arrow_x = 6
arrow_y = 3

arrow_prperties = dict(facecolor="red",width=0.5,headwidth=5,shrink=0.1)

plt.annotate("maximum",xy=(arrow_x,arrow_y),xytext=(label_x,label_y),arrowprops=arrow_prperties)
plt.plot(x,y)

# %%
ip=[11,22,33,44,55]
#o/p=[44,55,11,22,33]
step=3
for i in range(0,step):
    ip[i],ip[i+1]=ip[i+1],ip[i]
print(ip)
# Out:
# [22, 33, 44, 11, 55]

# %%
list1=[10,25,45,85,96,14]
sum=0
for i in range(0,len(list1)):
    sum = sum+list1[i]
mean = sum/len(list1)
print(sum)
print(mean)
# Out:
# 275
# 45.833333333333336

# %%
#list=['a','b','c','d','e','f','g']
#o/p=['d','b','c','g','e','f','a']
